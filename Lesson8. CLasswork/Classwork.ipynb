# %%
# !dir
# Out:
#  ’®¬ ў гбва®©бвўҐ C ­Ґ Ё¬ҐҐв ¬ҐвЄЁ.
#  ‘ҐаЁ©­л© ­®¬Ґа в®¬ : 12F4-36BF
#
#  ‘®¤Ґа¦Ё¬®Ґ Ї ЇЄЁ C:\Users\ЉЁаЁ««\Desktop\nordic_data_science\Lesson8. CLasswork
#
# 23.03.2021  19:49    <DIR>          .
# 23.03.2021  19:49    <DIR>          ..
# 23.03.2021  19:01    <DIR>          .ipynb_checkpoints
# 23.03.2021  19:49             5я273 Classwork.ipynb
# 23.03.2021  19:48                24 test.txt
#                2 д ©«®ў          5я297 Ў ©в
#                3 Ї Ї®Є  74я458я398я720 Ў ©в бў®Ў®¤­®

# %%
f = open('test.txt', 'w')

# %%
asd = "Hello world!"
f.write(asd)
# Out:
# 12

# %%
f.close()

# %%
f = open('test.txt', 'r')

# %%
f.read()
# Out:
# 'Hello world!Hello world!Hello world!Hello world!Hello world!Hello world!'

# %%
f.close()

# %%
f.tell()
# Out:
# 12

# %%
f.seek(0)
# Out:
# 0

# %%
f.read(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-8013280f4ff8> in <module>
# ----> 1 f.read(5)
#
# ValueError: I/O operation on closed file.

# %%
with open('test.txt', 'w') as f:
    f.write(asd)
    f.write(asd)

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-571e9fb02258> in <module>
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %%
asd = "Hello world! "

# %%
with open('folder/file.txt', 'r', encoding = 'UTF-8') as f:
#     print(f.read())
    for s in f:
        print(s)
# Out:
# Привет! Как дела? Hello world!
#
# Hello world!
#
# Hello world!
#
# Hello world!

# %%
text = '''Ехали медведи
На велосипеде.

А за ними кот
Задом наперёд.

А за ним комарики
На воздушном шарике.

А за ними раки
На хромой собаке.

Волки на кобыле.
Львы в автомобиле.

Зайчики
в трамвайчике.

Жаба на метле…

Едут и смеются,
Пряники жуют.

Вдруг из подворотни
Страшный великан,
Рыжий и усатый
Та-ра-кан!
Таракан, Таракан, Тараканище!

Он рычит, и кричит,
И усами шевелит:
«Погодите, не спешите,
Я вас мигом проглочу!
Проглочу, проглочу, не помилую».

Звери задрожали,
В обморок упали.

Волки от испуга
Скушали друг друга.

Бедный крокодил
Жабу проглотил.

А слониха, вся дрожа,
Так и села на ежа.

Только раки-забияки
Не боятся бою-драки;
Хоть и пятятся назад,
Но усами шевелят
И кричат великану усатому:

«Не кричи и не рычи,
Мы и сами усачи,
Можем мы и сами
Шевелить усами!»
И назад еще дальше попятились.

И сказал Гиппопотам
Крокодилам и китам:

«Кто злодея не боится
И с чудовищем сразится,
Я тому богатырю
Двух лягушек подарю
И еловую шишку пожалую!»

«Не боимся мы его,
Великана твоего:
Мы зубами,
Мы клыками,
Мы копытами его!»

И весёлою гурьбой
Звери кинулися в бой.

Но, увидев усача
(Ай-ай-ай!),
Звери дали стрекоча
(Ай-ай-ай!).

По лесам, по полям разбежалися:
Тараканьих усов испугалися.

И вскричал Гиппопотам:
«Что за стыд, что за срам!
Эй, быки и носороги,
Выходите из берлоги
И врага
На рога
Поднимите-ка!»

Но быки и носороги
Отвечают из берлоги:
«Мы врага бы
На рога бы,
Только шкура дорога,
И рога нынче тоже не дёшевы».

И сидят и дрожат под кусточками,
За болотными прячутся кочками.

Крокодилы в крапиву забилися,
И в канаве слоны схоронилися.

Только и слышно, как зубы стучат,
Только и видно, как уши дрожат.

А лихие обезьяны
Подхватили чемоданы
И скорее со всех ног
Наутёк.

И акула
Увильнула,
Только хвостиком махнула.

А за нею каракатица —
Так и пятится,
Так и катится.

Вот и стал Таракан победителем,
И лесов и полей повелителем.
Покорилися звери усатому
(Чтоб ему провалиться, проклятому!).
А он между ними похаживает,
Золоченое брюхо поглаживает:
«Принесите-ка мне, звери, ваших детушек,
Я сегодня их за ужином скушаю!»

Бедные, бедные звери!
Воют, рыдают, ревут!
В каждой берлоге
И в каждой пещере
Злого обжору клянут.

Да и какая же мать
Согласится отдать
Своего дорогого ребёнка —
Медвежонка, волчонка, слонёнка, —
Чтоб ненасытное чучело
Бедную крошку замучило!

Плачут они, убиваются,
С малышами навеки прощаются.

Но однажды поутру
Прискакала кенгуру.
Увидала усача,
Закричала сгоряча:
«Разве это великан?
(Ха-ха-ха!)
Это просто таракан!
(Ха-ха-ха!)

Таракан, таракан, таракашечка,
Жидконогая козявочка-букашечка.
И не стыдно вам?
Не обидно вам?
Вы — зубастые,
Вы — клыкастые,
А малявочке
Поклонилися,
А козявочке
Покорилися!»

Испугались бегемоты,
Зашептали: «Что ты, что ты!
Уходи-ка ты отсюда!
Как бы не было нам худа!»

Только вдруг из-за кусточка,
Из-за синего лесочка,
Из далёких из полей
Прилетает Воробей.
Прыг да прыг!
Да чик-чирик,
Чики-рики-чик-чирик!

Взял и клюнул Таракана —
Вот и нету великана.
Поделом великану досталося,
И усов от него не осталося.

То-то рада, то-то рада
Вся звериная семья,
Прославляют, поздравляют
Удалого Воробья!

Ослы ему славу по нотам поют,
Козлы бородою дорогу метут,
Бараны, бараны
Стучат в барабаны!
Сычи-трубачи
Трубят!
Грачи с каланчи
Кричат!
Летучие мыши
На крыше
Платочками машут
И пляшут.

А слониха-щеголиха
Так отплясывает лихо,
Что румяная луна
В небе задрожала
И на бедного слона
Кубарем упала.

Вот была потом забота —
За луной нырять в болото
И гвоздями к небесам приколачивать!'''

# %%
from collections import Counter

# %%
 a = text.lower().split()

# %%
a
# Out:
# ['ехали',
#  'медведи',
#  'на',
#  'велосипеде.',
#  'а',
#  'за',
#  'ними',
#  'кот',
#  'задом',
#  'наперёд.',
#  'а',
#  'за',
#  'ним',
#  'комарики',
#  'на',
#  'воздушном',
#  'шарике.',
#  'а',
#  'за',
#  'ними',
#  'раки',
#  'на',
#  'хромой',
#  'собаке.',
#  'волки',
#  'на',
#  'кобыле.',
#  'львы',
#  'в',
#  'автомобиле.',
#  'зайчики',
#  'в',
#  'трамвайчике.',
#  'жаба',
#  'на',
#  'метле…',
#  'едут',
#  'и',
#  'смеются,',
#  'пряники',
#  'жуют.',
#  'вдруг',
#  'из',
#  'подворотни',
#  'страшный',
#  'великан,',
#  'рыжий',
#  'и',
#  'усатый',
#  'та-ра-кан!',
#  'таракан,',
#  'таракан,',
#  'тараканище!',
#  'он',
#  'рычит,',
#  'и',
#  'кричит,',
#  'и',
#  'усами',
#  'шевелит:',
#  '«погодите,',
#  'не',
#  'спешите,',
#  'я',
#  'вас',
#  'мигом',
#  'проглочу!',
#  'проглочу,',
#  'проглочу,',
#  'не',
#  'помилую».',
#  'звери',
#  'задрожали,',
#  'в',
#  'обморок',
#  'упали.',
#  'волки',
#  'от',
#  'испуга',
#  'скушали',
#  'друг',
#  'друга.',
#  'бедный',
#  'крокодил',
#  'жабу',
#  'проглотил.',
#  'а',
#  'слониха,',
#  'вся',
#  'дрожа,',
#  'так',
#  'и',
#  'села',
#  'на',
#  'ежа.',
#  'только',
#  'раки-забияки',
#  'не',
#  'боятся',
#  'бою-драки;',
#  'хоть',
#  'и',
#  'пятятся',
#  'назад,',
#  'но',
#  'усами',
#  'шевелят',
#  'и',
#  'кричат',
#  'великану',
#  'усатому:',
#  '«не',
#  'кричи',
#  'и',
#  'не',
#  'рычи,',
#  'мы',
#  'и',
#  'сами',
#  'усачи,',
#  'можем',
#  'мы',
#  'и',
#  'сами',
#  'шевелить',
#  'усами!»',
#  'и',
#  'назад',
#  'еще',
#  'дальше',
#  'попятились.',
#  'и',
#  'сказал',
#  'гиппопотам',
#  'крокодилам',
#  'и',
#  'китам:',
#  '«кто',
#  'злодея',
#  'не',
#  'боится',
#  'и',
#  'с',
#  'чудовищем',
#  'сразится,',
#  'я',
#  'тому',
#  'богатырю',
#  'двух',
#  'лягушек',
#  'подарю',
#  'и',
#  'еловую',
#  'шишку',
#  'пожалую!»',
#  '«не',
#  'боимся',
#  'мы',
#  'его,',
#  'великана',
#  'твоего:',
#  'мы',
#  'зубами,',
#  'мы',
#  'клыками,',
#  'мы',
#  'копытами',
#  'его!»',
#  'и',
#  'весёлою',
#  'гурьбой',
#  'звери',
#  'кинулися',
#  'в',
#  'бой.',
#  'но,',
#  'увидев',
#  'усача',
#  '(ай-ай-ай!),',
#  'звери',
#  'дали',
#  'стрекоча',
#  '(ай-ай-ай!).',
#  'по',
#  'лесам,',
#  'по',
#  'полям',
#  'разбежалися:',
#  'тараканьих',
#  'усов',
#  'испугалися.',
#  'и',
#  'вскричал',
#  'гиппопотам:',
#  '«что',
#  'за',
#  'стыд,',
#  'что',
#  'за',
#  'срам!',
#  'эй,',
#  'быки',
#  'и',
#  'носороги,',
#  'выходите',
#  'из',
#  'берлоги',
#  'и',
#  'врага',
#  'на',
#  'рога',
#  'поднимите-ка!»',
#  'но',
#  'быки',
#  'и',
#  'носороги',
#  'отвечают',
#  'из',
#  'берлоги:',
#  '«мы',
#  'врага',
#  'бы',
#  'на',
#  'рога',
#  'бы,',
#  'только',
#  'шкура',
#  'дорога,',
#  'и',
#  'рога',
#  'нынче',
#  'тоже',
#  'не',
#  'дёшевы».',
#  'и',
#  'сидят',
#  'и',
#  'дрожат',
#  'под',
#  'кусточками,',
#  'за',
#  'болотными',
#  'прячутся',
#  'кочками.',
#  'крокодилы',
#  'в',
#  'крапиву',
#  'забилися,',
#  'и',
#  'в',
#  'канаве',
#  'слоны',
#  'схоронилися.',
#  'только',
#  'и',
#  'слышно,',
#  'как',
#  'зубы',
#  'стучат,',
#  'только',
#  'и',
#  'видно,',
#  'как',
#  'уши',
#  'дрожат.',
#  'а',
#  'лихие',
#  'обезьяны',
#  'подхватили',
#  'чемоданы',
#  'и',
#  'скорее',
#  'со',
#  'всех',
#  'ног',
#  'наутёк.',
#  'и',
#  'акула',
#  'увильнула,',
#  'только',
#  'хвостиком',
#  'махнула.',
#  'а',
#  'за',
#  'нею',
#  'каракатица',
#  '—',
#  'так',
#  'и',
#  'пятится,',
#  'так',
#  'и',
#  'катится.',
#  'вот',
#  'и',
#  'стал',
#  'таракан',
#  'победителем,',
#  'и',
#  'лесов',
#  'и',
#  'полей',
#  'повелителем.',
#  'покорилися',
#  'звери',
#  'усатому',
#  '(чтоб',
#  'ему',
#  'провалиться,',
#  'проклятому!).',
#  'а',
#  'он',
#  'между',
#  'ними',
#  'похаживает,',
#  'золоченое',
#  'брюхо',
#  'поглаживает:',
#  '«принесите-ка',
#  'мне,',
#  'звери,',
#  'ваших',
#  'детушек,',
#  'я',
#  'сегодня',
#  'их',
#  'за',
#  'ужином',
#  'скушаю!»',
#  'бедные,',
#  'бедные',
#  'звери!',
#  'воют,',
#  'рыдают,',
#  'ревут!',
#  'в',
#  'каждой',
#  'берлоге',
#  'и',
#  'в',
#  'каждой',
#  'пещере',
#  'злого',
#  'обжору',
#  'клянут.',
#  'да',
#  'и',
#  'какая',
#  'же',
#  'мать',
#  'согласится',
#  'отдать',
#  'своего',
#  'дорогого',
#  'ребёнка',
#  '—',
#  'медвежонка,',
#  'волчонка,',
#  'слонёнка,',
#  '—',
#  'чтоб',
#  'ненасытное',
#  'чучело',
#  'бедную',
#  'крошку',
#  'замучило!',
#  'плачут',
#  'они,',
#  'убиваются,',
#  'с',
#  'малышами',
#  'навеки',
#  'прощаются.',
#  'но',
#  'однажды',
#  'поутру',
#  'прискакала',
#  'кенгуру.',
#  'увидала',
#  'усача,',
#  'закричала',
#  'сгоряча:',
#  '«разве',
#  'это',
#  'великан?',
#  '(ха-ха-ха!)',
#  'это',
#  'просто',
#  'таракан!',
#  '(ха-ха-ха!)',
#  'таракан,',
#  'таракан,',
#  'таракашечка,',
#  'жидконогая',
#  'козявочка-букашечка.',
#  'и',
#  'не',
#  'стыдно',
#  'вам?',
#  'не',
#  'обидно',
#  'вам?',
#  'вы',
#  '—',
#  'зубастые,',
#  'вы',
#  '—',
#  'клыкастые,',
#  'а',
#  'малявочке',
#  'поклонилися,',
#  'а',
#  'козявочке',
#  'покорилися!»',
#  'испугались',
#  'бегемоты,',
#  'зашептали:',
#  '«что',
#  'ты,',
#  'что',
#  'ты!',
#  'уходи-ка',
#  'ты',
#  'отсюда!',
#  'как',
#  'бы',
#  'не',
#  'было',
#  'нам',
#  'худа!»',
#  'только',
#  'вдруг',
#  'из-за',
#  'кусточка,',
#  'из-за',
#  'синего',
#  'лесочка,',
#  'из',
#  'далёких',
#  'из',
#  'полей',
#  'прилетает',
#  'воробей.',
#  'прыг',
#  'да',
#  'прыг!',
#  'да',
#  'чик-чирик,',
#  'чики-рики-чик-чирик!',
#  'взял',
#  'и',
#  'клюнул',
#  'таракана',
#  '—',
#  'вот',
#  'и',
#  'нету',
#  'великана.',
#  'поделом',
#  'великану',
#  'досталося,',
#  'и',
#  'усов',
#  'от',
#  'него',
#  'не',
#  'осталося.',
#  'то-то',
#  'рада,',
#  'то-то',
#  'рада',
#  'вся',
#  'звериная',
#  'семья,',
#  'прославляют,',
#  'поздравляют',
#  'удалого',
#  'воробья!',
#  'ослы',
#  'ему',
#  'славу',
#  'по',
#  'нотам',
#  'поют,',
#  'козлы',
#  'бородою',
#  'дорогу',
#  'метут,',
#  'бараны,',
#  'бараны',
#  'стучат',
#  'в',
#  'барабаны!',
#  'сычи-трубачи',
#  'трубят!',
#  'грачи',
#  'с',
#  'каланчи',
#  'кричат!',
#  'летучие',
#  'мыши',
#  'на',
#  'крыше',
#  'платочками',
#  'машут',
#  'и',
#  'пляшут.',
#  'а',
#  'слониха-щеголиха',
#  'так',
#  'отплясывает',
#  'лихо,',
#  'что',
#  'румяная',
#  'луна',
#  'в',
#  'небе',
#  'задрожала',
#  'и',
#  'на',
#  'бедного',
#  'слона',
#  'кубарем',
#  'упала.',
#  'вот',
#  'была',
#  'потом',
#  'забота',
#  '—',
#  'за',
#  'луной',
#  'нырять',
#  'в',
#  'болото',
#  'и',
#  'гвоздями',
#  'к',
#  'небесам',
#  'приколачивать!']

# %%
 c = Counter(a)

# %%
c
# Out:
# Counter({'ехали': 1,
#          'медведи': 1,
#          'на': 10,
#          'велосипеде.': 1,
#          'а': 10,
#          'за': 9,
#          'ними': 3,
#          'кот': 1,
#          'задом': 1,
#          'наперёд.': 1,
#          'ним': 1,
#          'комарики': 1,
#          'воздушном': 1,
#          'шарике.': 1,
#          'раки': 1,
#          'хромой': 1,
#          'собаке.': 1,
#          'волки': 2,
#          'кобыле.': 1,
#          'львы': 1,
#          'в': 11,
#          'автомобиле.': 1,
#          'зайчики': 1,
#          'трамвайчике.': 1,
#          'жаба': 1,
#          'метле…': 1,
#          'едут': 1,
#          'и': 42,
#          'смеются,': 1,
#          'пряники': 1,
#          'жуют.': 1,
#          'вдруг': 2,
#          'из': 5,
#          'подворотни': 1,
#          'страшный': 1,
#          'великан,': 1,
#          'рыжий': 1,
#          'усатый': 1,
#          'та-ра-кан!': 1,
#          'таракан,': 4,
#          'тараканище!': 1,
#          'он': 2,
#          'рычит,': 1,
#          'кричит,': 1,
#          'усами': 2,
#          'шевелит:': 1,
#          '«погодите,': 1,
#          'не': 10,
#          'спешите,': 1,
#          'я': 3,
#          'вас': 1,
#          'мигом': 1,
#          'проглочу!': 1,
#          'проглочу,': 2,
#          'помилую».': 1,
#          'звери': 4,
#          'задрожали,': 1,
#          'обморок': 1,
#          'упали.': 1,
#          'от': 2,
#          'испуга': 1,
#          'скушали': 1,
#          'друг': 1,
#          'друга.': 1,
#          'бедный': 1,
#          'крокодил': 1,
#          'жабу': 1,
#          'проглотил.': 1,
#          'слониха,': 1,
#          'вся': 2,
#          'дрожа,': 1,
#          'так': 4,
#          'села': 1,
#          'ежа.': 1,
#          'только': 6,
#          'раки-забияки': 1,
#          'боятся': 1,
#          'бою-драки;': 1,
#          'хоть': 1,
#          'пятятся': 1,
#          'назад,': 1,
#          'но': 3,
#          'шевелят': 1,
#          'кричат': 1,
#          'великану': 2,
#          'усатому:': 1,
#          '«не': 2,
#          'кричи': 1,
#          'рычи,': 1,
#          'мы': 6,
#          'сами': 2,
#          'усачи,': 1,
#          'можем': 1,
#          'шевелить': 1,
#          'усами!»': 1,
#          'назад': 1,
#          'еще': 1,
#          'дальше': 1,
#          'попятились.': 1,
#          'сказал': 1,
#          'гиппопотам': 1,
#          'крокодилам': 1,
#          'китам:': 1,
#          '«кто': 1,
#          'злодея': 1,
#          'боится': 1,
#          'с': 3,
#          'чудовищем': 1,
#          'сразится,': 1,
#          'тому': 1,
#          'богатырю': 1,
#          'двух': 1,
#          'лягушек': 1,
#          'подарю': 1,
#          'еловую': 1,
#          'шишку': 1,
#          'пожалую!»': 1,
#          'боимся': 1,
#          'его,': 1,
#          'великана': 1,
#          'твоего:': 1,
#          'зубами,': 1,
#          'клыками,': 1,
#          'копытами': 1,
#          'его!»': 1,
#          'весёлою': 1,
#          'гурьбой': 1,
#          'кинулися': 1,
#          'бой.': 1,
#          'но,': 1,
#          'увидев': 1,
#          'усача': 1,
#          '(ай-ай-ай!),': 1,
#          'дали': 1,
#          'стрекоча': 1,
#          '(ай-ай-ай!).': 1,
#          'по': 3,
#          'лесам,': 1,
#          'полям': 1,
#          'разбежалися:': 1,
#          'тараканьих': 1,
#          'усов': 2,
#          'испугалися.': 1,
#          'вскричал': 1,
#          'гиппопотам:': 1,
#          '«что': 2,
#          'стыд,': 1,
#          'что': 3,
#          'срам!': 1,
#          'эй,': 1,
#          'быки': 2,
#          'носороги,': 1,
#          'выходите': 1,
#          'берлоги': 1,
#          'врага': 2,
#          'рога': 3,
#          'поднимите-ка!»': 1,
#          'носороги': 1,
#          'отвечают': 1,
#          'берлоги:': 1,
#          '«мы': 1,
#          'бы': 2,
#          'бы,': 1,
#          'шкура': 1,
#          'дорога,': 1,
#          'нынче': 1,
#          'тоже': 1,
#          'дёшевы».': 1,
#          'сидят': 1,
#          'дрожат': 1,
#          'под': 1,
#          'кусточками,': 1,
#          'болотными': 1,
#          'прячутся': 1,
#          'кочками.': 1,
#          'крокодилы': 1,
#          'крапиву': 1,
#          'забилися,': 1,
#          'канаве': 1,
#          'слоны': 1,
#          'схоронилися.': 1,
#          'слышно,': 1,
#          'как': 3,
#          'зубы': 1,
#          'стучат,': 1,
#          'видно,': 1,
#          'уши': 1,
#          'дрожат.': 1,
#          'лихие': 1,
#          'обезьяны': 1,
#          'подхватили': 1,
#          'чемоданы': 1,
#          'скорее': 1,
#          'со': 1,
#          'всех': 1,
#          'ног': 1,
#          'наутёк.': 1,
#          'акула': 1,
#          'увильнула,': 1,
#          'хвостиком': 1,
#          'махнула.': 1,
#          'нею': 1,
#          'каракатица': 1,
#          '—': 7,
#          'пятится,': 1,
#          'катится.': 1,
#          'вот': 3,
#          'стал': 1,
#          'таракан': 1,
#          'победителем,': 1,
#          'лесов': 1,
#          'полей': 2,
#          'повелителем.': 1,
#          'покорилися': 1,
#          'усатому': 1,
#          '(чтоб': 1,
#          'ему': 2,
#          'провалиться,': 1,
#          'проклятому!).': 1,
#          'между': 1,
#          'похаживает,': 1,
#          'золоченое': 1,
#          'брюхо': 1,
#          'поглаживает:': 1,
#          '«принесите-ка': 1,
#          'мне,': 1,
#          'звери,': 1,
#          'ваших': 1,
#          'детушек,': 1,
#          'сегодня': 1,
#          'их': 1,
#          'ужином': 1,
#          'скушаю!»': 1,
#          'бедные,': 1,
#          'бедные': 1,
#          'звери!': 1,
#          'воют,': 1,
#          'рыдают,': 1,
#          'ревут!': 1,
#          'каждой': 2,
#          'берлоге': 1,
#          'пещере': 1,
#          'злого': 1,
#          'обжору': 1,
#          'клянут.': 1,
#          'да': 3,
#          'какая': 1,
#          'же': 1,
#          'мать': 1,
#          'согласится': 1,
#          'отдать': 1,
#          'своего': 1,
#          'дорогого': 1,
#          'ребёнка': 1,
#          'медвежонка,': 1,
#          'волчонка,': 1,
#          'слонёнка,': 1,
#          'чтоб': 1,
#          'ненасытное': 1,
#          'чучело': 1,
#          'бедную': 1,
#          'крошку': 1,
#          'замучило!': 1,
#          'плачут': 1,
#          'они,': 1,
#          'убиваются,': 1,
#          'малышами': 1,
#          'навеки': 1,
#          'прощаются.': 1,
#          'однажды': 1,
#          'поутру': 1,
#          'прискакала': 1,
#          'кенгуру.': 1,
#          'увидала': 1,
#          'усача,': 1,
#          'закричала': 1,
#          'сгоряча:': 1,
#          '«разве': 1,
#          'это': 2,
#          'великан?': 1,
#          '(ха-ха-ха!)': 2,
#          'просто': 1,
#          'таракан!': 1,
#          'таракашечка,': 1,
#          'жидконогая': 1,
#          'козявочка-букашечка.': 1,
#          'стыдно': 1,
#          'вам?': 2,
#          'обидно': 1,
#          'вы': 2,
#          'зубастые,': 1,
#          'клыкастые,': 1,
#          'малявочке': 1,
#          'поклонилися,': 1,
#          'козявочке': 1,
#          'покорилися!»': 1,
#          'испугались': 1,
#          'бегемоты,': 1,
#          'зашептали:': 1,
#          'ты,': 1,
#          'ты!': 1,
#          'уходи-ка': 1,
#          'ты': 1,
#          'отсюда!': 1,
#          'было': 1,
#          'нам': 1,
#          'худа!»': 1,
#          'из-за': 2,
#          'кусточка,': 1,
#          'синего': 1,
#          'лесочка,': 1,
#          'далёких': 1,
#          'прилетает': 1,
#          'воробей.': 1,
#          'прыг': 1,
#          'прыг!': 1,
#          'чик-чирик,': 1,
#          'чики-рики-чик-чирик!': 1,
#          'взял': 1,
#          'клюнул': 1,
#          'таракана': 1,
#          'нету': 1,
#          'великана.': 1,
#          'поделом': 1,
#          'досталося,': 1,
#          'него': 1,
#          'осталося.': 1,
#          'то-то': 2,
#          'рада,': 1,
#          'рада': 1,
#          'звериная': 1,
#          'семья,': 1,
#          'прославляют,': 1,
#          'поздравляют': 1,
#          'удалого': 1,
#          'воробья!': 1,
#          'ослы': 1,
#          'славу': 1,
#          'нотам': 1,
#          'поют,': 1,
#          'козлы': 1,
#          'бородою': 1,
#          'дорогу': 1,
#          'метут,': 1,
#          'бараны,': 1,
#          'бараны': 1,
#          'стучат': 1,
#          'барабаны!': 1,
#          'сычи-трубачи': 1,
#          'трубят!': 1,
#          'грачи': 1,
#          'каланчи': 1,
#          'кричат!': 1,
#          'летучие': 1,
#          'мыши': 1,
#          'крыше': 1,
#          'платочками': 1,
#          'машут': 1,
#          'пляшут.': 1,
#          'слониха-щеголиха': 1,
#          'отплясывает': 1,
#          'лихо,': 1,
#          'румяная': 1,
#          'луна': 1,
#          'небе': 1,
#          'задрожала': 1,
#          'бедного': 1,
#          'слона': 1,
#          'кубарем': 1,
#          'упала.': 1,
#          'была': 1,
#          'потом': 1,
#          'забота': 1,
#          'луной': 1,
#          'нырять': 1,
#          'болото': 1,
#          'гвоздями': 1,
#          'к': 1,
#          'небесам': 1,
#          'приколачивать!': 1})

# %%
c.most_common(10)
# Out:
# [('и', 42),
#  ('в', 11),
#  ('на', 10),
#  ('а', 10),
#  ('не', 10),
#  ('за', 9),
#  ('—', 7),
#  ('только', 6),
#  ('мы', 6),
#  ('из', 5)]

# %%
stop_wd = ["из", "с","на","в","и","за","а","бы", "к","не","—","так","но","по","как","вот","что","вдруг","да","только","от"]

# %%
for wb in stop_wd:
    c.pop(wb)

# %%
c.most_common()
# Out:
# [('мы', 6),
#  ('таракан,', 4),
#  ('звери', 4),
#  ('ними', 3),
#  ('я', 3),
#  ('рога', 3),
#  ('волки', 2),
#  ('он', 2),
#  ('усами', 2),
#  ('проглочу,', 2),
#  ('вся', 2),
#  ('великану', 2),
#  ('«не', 2),
#  ('сами', 2),
#  ('усов', 2),
#  ('«что', 2),
#  ('быки', 2),
#  ('врага', 2),
#  ('полей', 2),
#  ('ему', 2),
#  ('каждой', 2),
#  ('это', 2),
#  ('(ха-ха-ха!)', 2),
#  ('вам?', 2),
#  ('вы', 2),
#  ('из-за', 2),
#  ('то-то', 2),
#  ('ехали', 1),
#  ('медведи', 1),
#  ('велосипеде.', 1),
#  ('кот', 1),
#  ('задом', 1),
#  ('наперёд.', 1),
#  ('ним', 1),
#  ('комарики', 1),
#  ('воздушном', 1),
#  ('шарике.', 1),
#  ('раки', 1),
#  ('хромой', 1),
#  ('собаке.', 1),
#  ('кобыле.', 1),
#  ('львы', 1),
#  ('автомобиле.', 1),
#  ('зайчики', 1),
#  ('трамвайчике.', 1),
#  ('жаба', 1),
#  ('метле…', 1),
#  ('едут', 1),
#  ('смеются,', 1),
#  ('пряники', 1),
#  ('жуют.', 1),
#  ('подворотни', 1),
#  ('страшный', 1),
#  ('великан,', 1),
#  ('рыжий', 1),
#  ('усатый', 1),
#  ('та-ра-кан!', 1),
#  ('тараканище!', 1),
#  ('рычит,', 1),
#  ('кричит,', 1),
#  ('шевелит:', 1),
#  ('«погодите,', 1),
#  ('спешите,', 1),
#  ('вас', 1),
#  ('мигом', 1),
#  ('проглочу!', 1),
#  ('помилую».', 1),
#  ('задрожали,', 1),
#  ('обморок', 1),
#  ('упали.', 1),
#  ('испуга', 1),
#  ('скушали', 1),
#  ('друг', 1),
#  ('друга.', 1),
#  ('бедный', 1),
#  ('крокодил', 1),
#  ('жабу', 1),
#  ('проглотил.', 1),
#  ('слониха,', 1),
#  ('дрожа,', 1),
#  ('села', 1),
#  ('ежа.', 1),
#  ('раки-забияки', 1),
#  ('боятся', 1),
#  ('бою-драки;', 1),
#  ('хоть', 1),
#  ('пятятся', 1),
#  ('назад,', 1),
#  ('шевелят', 1),
#  ('кричат', 1),
#  ('усатому:', 1),
#  ('кричи', 1),
#  ('рычи,', 1),
#  ('усачи,', 1),
#  ('можем', 1),
#  ('шевелить', 1),
#  ('усами!»', 1),
#  ('назад', 1),
#  ('еще', 1),
#  ('дальше', 1),
#  ('попятились.', 1),
#  ('сказал', 1),
#  ('гиппопотам', 1),
#  ('крокодилам', 1),
#  ('китам:', 1),
#  ('«кто', 1),
#  ('злодея', 1),
#  ('боится', 1),
#  ('чудовищем', 1),
#  ('сразится,', 1),
#  ('тому', 1),
#  ('богатырю', 1),
#  ('двух', 1),
#  ('лягушек', 1),
#  ('подарю', 1),
#  ('еловую', 1),
#  ('шишку', 1),
#  ('пожалую!»', 1),
#  ('боимся', 1),
#  ('его,', 1),
#  ('великана', 1),
#  ('твоего:', 1),
#  ('зубами,', 1),
#  ('клыками,', 1),
#  ('копытами', 1),
#  ('его!»', 1),
#  ('весёлою', 1),
#  ('гурьбой', 1),
#  ('кинулися', 1),
#  ('бой.', 1),
#  ('но,', 1),
#  ('увидев', 1),
#  ('усача', 1),
#  ('(ай-ай-ай!),', 1),
#  ('дали', 1),
#  ('стрекоча', 1),
#  ('(ай-ай-ай!).', 1),
#  ('лесам,', 1),
#  ('полям', 1),
#  ('разбежалися:', 1),
#  ('тараканьих', 1),
#  ('испугалися.', 1),
#  ('вскричал', 1),
#  ('гиппопотам:', 1),
#  ('стыд,', 1),
#  ('срам!', 1),
#  ('эй,', 1),
#  ('носороги,', 1),
#  ('выходите', 1),
#  ('берлоги', 1),
#  ('поднимите-ка!»', 1),
#  ('носороги', 1),
#  ('отвечают', 1),
#  ('берлоги:', 1),
#  ('«мы', 1),
#  ('бы,', 1),
#  ('шкура', 1),
#  ('дорога,', 1),
#  ('нынче', 1),
#  ('тоже', 1),
#  ('дёшевы».', 1),
#  ('сидят', 1),
#  ('дрожат', 1),
#  ('под', 1),
#  ('кусточками,', 1),
#  ('болотными', 1),
#  ('прячутся', 1),
#  ('кочками.', 1),
#  ('крокодилы', 1),
#  ('крапиву', 1),
#  ('забилися,', 1),
#  ('канаве', 1),
#  ('слоны', 1),
#  ('схоронилися.', 1),
#  ('слышно,', 1),
#  ('зубы', 1),
#  ('стучат,', 1),
#  ('видно,', 1),
#  ('уши', 1),
#  ('дрожат.', 1),
#  ('лихие', 1),
#  ('обезьяны', 1),
#  ('подхватили', 1),
#  ('чемоданы', 1),
#  ('скорее', 1),
#  ('со', 1),
#  ('всех', 1),
#  ('ног', 1),
#  ('наутёк.', 1),
#  ('акула', 1),
#  ('увильнула,', 1),
#  ('хвостиком', 1),
#  ('махнула.', 1),
#  ('нею', 1),
#  ('каракатица', 1),
#  ('пятится,', 1),
#  ('катится.', 1),
#  ('стал', 1),
#  ('таракан', 1),
#  ('победителем,', 1),
#  ('лесов', 1),
#  ('повелителем.', 1),
#  ('покорилися', 1),
#  ('усатому', 1),
#  ('(чтоб', 1),
#  ('провалиться,', 1),
#  ('проклятому!).', 1),
#  ('между', 1),
#  ('похаживает,', 1),
#  ('золоченое', 1),
#  ('брюхо', 1),
#  ('поглаживает:', 1),
#  ('«принесите-ка', 1),
#  ('мне,', 1),
#  ('звери,', 1),
#  ('ваших', 1),
#  ('детушек,', 1),
#  ('сегодня', 1),
#  ('их', 1),
#  ('ужином', 1),
#  ('скушаю!»', 1),
#  ('бедные,', 1),
#  ('бедные', 1),
#  ('звери!', 1),
#  ('воют,', 1),
#  ('рыдают,', 1),
#  ('ревут!', 1),
#  ('берлоге', 1),
#  ('пещере', 1),
#  ('злого', 1),
#  ('обжору', 1),
#  ('клянут.', 1),
#  ('какая', 1),
#  ('же', 1),
#  ('мать', 1),
#  ('согласится', 1),
#  ('отдать', 1),
#  ('своего', 1),
#  ('дорогого', 1),
#  ('ребёнка', 1),
#  ('медвежонка,', 1),
#  ('волчонка,', 1),
#  ('слонёнка,', 1),
#  ('чтоб', 1),
#  ('ненасытное', 1),
#  ('чучело', 1),
#  ('бедную', 1),
#  ('крошку', 1),
#  ('замучило!', 1),
#  ('плачут', 1),
#  ('они,', 1),
#  ('убиваются,', 1),
#  ('малышами', 1),
#  ('навеки', 1),
#  ('прощаются.', 1),
#  ('однажды', 1),
#  ('поутру', 1),
#  ('прискакала', 1),
#  ('кенгуру.', 1),
#  ('увидала', 1),
#  ('усача,', 1),
#  ('закричала', 1),
#  ('сгоряча:', 1),
#  ('«разве', 1),
#  ('великан?', 1),
#  ('просто', 1),
#  ('таракан!', 1),
#  ('таракашечка,', 1),
#  ('жидконогая', 1),
#  ('козявочка-букашечка.', 1),
#  ('стыдно', 1),
#  ('обидно', 1),
#  ('зубастые,', 1),
#  ('клыкастые,', 1),
#  ('малявочке', 1),
#  ('поклонилися,', 1),
#  ('козявочке', 1),
#  ('покорилися!»', 1),
#  ('испугались', 1),
#  ('бегемоты,', 1),
#  ('зашептали:', 1),
#  ('ты,', 1),
#  ('ты!', 1),
#  ('уходи-ка', 1),
#  ('ты', 1),
#  ('отсюда!', 1),
#  ('было', 1),
#  ('нам', 1),
#  ('худа!»', 1),
#  ('кусточка,', 1),
#  ('синего', 1),
#  ('лесочка,', 1),
#  ('далёких', 1),
#  ('прилетает', 1),
#  ('воробей.', 1),
#  ('прыг', 1),
#  ('прыг!', 1),
#  ('чик-чирик,', 1),
#  ('чики-рики-чик-чирик!', 1),
#  ('взял', 1),
#  ('клюнул', 1),
#  ('таракана', 1),
#  ('нету', 1),
#  ('великана.', 1),
#  ('поделом', 1),
#  ('досталося,', 1),
#  ('него', 1),
#  ('осталося.', 1),
#  ('рада,', 1),
#  ('рада', 1),
#  ('звериная', 1),
#  ('семья,', 1),
#  ('прославляют,', 1),
#  ('поздравляют', 1),
#  ('удалого', 1),
#  ('воробья!', 1),
#  ('ослы', 1),
#  ('славу', 1),
#  ('нотам', 1),
#  ('поют,', 1),
#  ('козлы', 1),
#  ('бородою', 1),
#  ('дорогу', 1),
#  ('метут,', 1),
#  ('бараны,', 1),
#  ('бараны', 1),
#  ('стучат', 1),
#  ('барабаны!', 1),
#  ('сычи-трубачи', 1),
#  ('трубят!', 1),
#  ('грачи', 1),
#  ('каланчи', 1),
#  ('кричат!', 1),
#  ('летучие', 1),
#  ('мыши', 1),
#  ('крыше', 1),
#  ('платочками', 1),
#  ('машут', 1),
#  ('пляшут.', 1),
#  ('слониха-щеголиха', 1),
#  ('отплясывает', 1),
#  ('лихо,', 1),
#  ('румяная', 1),
#  ('луна', 1),
#  ('небе', 1),
#  ('задрожала', 1),
#  ('бедного', 1),
#  ('слона', 1),
#  ('кубарем', 1),
#  ('упала.', 1),
#  ('была', 1),
#  ('потом', 1),
#  ('забота', 1),
#  ('луной', 1),
#  ('нырять', 1),
#  ('болото', 1),
#  ('гвоздями', 1),
#  ('небесам', 1),
#  ('приколачивать!', 1)]
