Молодого Комара!

Муравей, Муравей
Не жалеет лаптей, —
С Муравьихою попрыгивает
И букашечкам подмигивает:

«Вы букашечки,
Вы милашечки,
Тара-тара-тара-тара
таракашечки!»

Сапоги скрипят,
Каблуки стучат, —
Будет, будет мошкара
Веселиться до утра:
Нынче Муха-Цокотуха
Именинница!"""

# %%
text.count('Муха')
# Out:
# 10

# %%
text = text.replace('!',".").replace('?','.').replace('\n',' ')
lst = text.split('.')
lst_count = []
for i in lst:
    lst_count.append(i.count('Муха'))
sum_count = 0
for k in lst_count:
    sum_count += k
print("Среднее количество слов Муха: "+ str(sum_count/len(lst_count)))
# Out:
# Среднее количество слов Муха: 0.24390243902439024

# %%
lst_1 = text.lower().split()
count = 0
for i in lst_1:
    for z in i:
        if ord(z) == 1072 or ord(z) == 1077 or ord(z) == 1105 or ord(z) == 1080 or ord(z) == 1086 or ord(z) == 1091 or ord(z) == 1099 or ord(z) == 1101 or ord(z) == 1102 or ord(z) == 1103:
            count += 1
print(count)
# Out:
# 829

# %%
lst_1 = text.lower().split()
count = 0
dict_ = {
    'а': 0,
    'е': 0,
    'ё': 0,
    'и': 0,
    'й': 0,
    'о': 0,
    'у': 0,
    'ы': 0,
    'э': 0,
    'ю': 0,
    'я': 0,
}
for i in lst_1:
    for z in i:
        if ord(z) == 1072 or ord(z) == 1077 or ord(z) == 1105 or ord(z) == 1080 or ord(z) == 1086 or ord(z) == 1091 or ord(z) == 1099 or ord(z) == 1101 or ord(z) == 1102 or ord(z) == 1103:
            dict_[z] += 1
count=0
dict_
# for i in dict_.values():
#     count+=i
# text = text.replace('!',".").replace('?','.').replace('\n',' ')
# lst = text.split('.')
# count/len(lst)
for z in list(dict_.keys()):
    dict_[z] = dict_[z]/41
dict_
# Out:
# {'а': 5.0,
#  'е': 3.4146341463414633,
#  'ё': 0.0975609756097561,
#  'и': 3.3902439024390243,
#  'й': 0.0,
#  'о': 4.317073170731708,
#  'у': 2.341463414634146,
#  'ы': 0.6585365853658537,
#  'э': 0.024390243902439025,
#  'ю': 0.24390243902439024,
#  'я': 0.7317073170731707}

# %%
dict_
# Out:
# {'а': 205,
#  'е': 140,
#  'ё': 4,
#  'и': 139,
#  'й': 0,
#  'о': 177,
#  'у': 96,
#  'ы': 27,
#  'э': 1,
#  'ю': 10,
#  'я': 30}
